# %% [markdown]
# <a href="https://colab.research.google.com/github/akshay-aiml/LangChain/blob/main/Prompt_Templates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install langchain langchain-community langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %%
from google.colab import userdata
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate,PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os

# %%
api_key = userdata.get("GROQ_API_KEY")
# Initialize LLM

llm = ChatGroq(
    api_key=api_key,
    model="llama-3.3-70b-versatile",
    temperature=0.2
)

# %% [markdown]
# PromptTemplate (Basic Text Prompt) -> Used for: Normal text-based LLMs

# %%
# Create Prompt Template
prompt = PromptTemplate.from_template(
    """
    You are an expert in political science and international relation.
    Explain {topic} in simple terms.
    Give a short example.
    """
)

# Create LCEL chain
chain = prompt | llm | StrOutputParser()

# Invoke the model
response = chain.invoke({"topic": " Trade war"})

print(response)
# Out:
# As an expert in political science and international relations, I'd be happy to explain trade wars in simple terms.
#
# **What is a Trade War?**
#
# A trade war is a situation where two or more countries impose tariffs (taxes) or other trade restrictions on each other's goods and services. This is usually done in response to a perceived unfair trade practice or to protect domestic industries. The goal is to limit the flow of goods and services between the countries and to gain a trade advantage.
#
# **How does it work?**
#
# Imagine you're a consumer in the United States, and you want to buy a Chinese-made smartphone. Normally, the phone would be imported into the US without any extra taxes. But, if the US government imposes a tariff on Chinese smartphones, the price of the phone would increase. This makes the Chinese phone more expensive for American consumers, which can lead to a decrease in sales.
#
# ...

# %% [markdown]
# # ChatPromptTemplate
# ChatPromptTemplate (For Chat Models) = Used for: Chat models like Groq, OpenAI, Gemini
#
# -> This returns chat message objects, not plain string.

# %%
# Create Chat Prompt Template

chat_prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms."
)

# Create chain
chain = chat_prompt | llm | StrOutputParser()

# Invoke chain
response = chain.invoke({"topic": "A2A protocol"})

print(response)
# Out:
# A2A (App-to-App) protocol is a way for different mobile apps to communicate with each other. Here's a simplified explanation:
#
# Imagine you have two apps on your phone: a social media app and a photo editing app. You want to share a photo from the photo editing app to the social media app.
#
# The A2A protocol allows these two apps to "talk" to each other, enabling you to share the photo directly from one app to the other. Here's how it works:
#
# 1. The photo editing app (the "source" app) sends a request to the social media app (the "target" app) to share the photo.
# 2. The social media app receives the request and responds with a list of available actions, such as "share" or "upload".
# 3. The photo editing app selects the desired action and sends the photo to the social media app.
# 4. The social media app receives the photo and allows you to share it with your friends or followers.
#
# ...

# %% [markdown]
# #Role-Based Chat Prompt
#
#  Role-Based Chat Prompt (System + Human)
#
# -> Because chat models understand roles:
#
# - `system` → **defines the behavior, tone, and rules of the model. (**behavior control)
# - `human` → user input
# - `ai` → model response

# %%
# Create Role-Based Chat Prompt
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI tutor who explains concepts clearly and simply."),
    ("human", "Explain {topic} in simple terms with a real-world example.")
])

# Create LCEL chain
chain = chat_prompt | llm | StrOutputParser()

# Invoke the chain
response = chain.invoke({"topic": "Transformer"})

print(response)
# Out:
# I'd be happy to explain the Transformer in simple terms with a real-world example.
#
# **What is a Transformer?**
#
# A Transformer is a type of artificial intelligence (AI) model that helps computers understand and process human language, like a super-smart language translator. It's mainly used for tasks like language translation, text summarization, and chatbots.
#
# **How does it work?**
#
# Imagine you're at a restaurant, and you want to order food in a language the waiter doesn't understand. You would use a translator to help communicate. The Transformer works in a similar way:
#
# 1. **Input**: You give the Transformer a sentence or text in one language (like English).
# 2. **Encoder**: The Transformer breaks down the input text into smaller parts, like individual words or phrases, and analyzes their meaning and context. This is like the translator listening to what you want to order.
# ...
